# %% [markdown]
# # Finding K2-twos: Campaign 11
#
# ### Outline
#
# * Query [2MASS All-Sky Point Source Catalog](http://irsa.ipac.caltech.edu/cgi-bin/Gator/nph-dd?catalog=fp_psc&mode=html&passproj&) for stars within:
#
#    * [Campaign 11](http://keplerscience.arc.nasa.gov/images/campaign_selected/field11-final.png) RA~(275,250), Dec~(-15, -33)
#    * [Campaign 12](http://keplerscience.arc.nasa.gov/images/campaign_selected/field12-final.png) RA~(343,362), Dec~(3,-14)
#    * [Campaign 13](http://keplerscience.arc.nasa.gov/images/campaign_selected/field13-final.png) RA~(63,82), Dec~(12,29)
#
# * If limited to J mags $11<J<8$, this gives us ~7600 sources for Campaign 8. I'm advocating for 2MASS here because the bright limit for SDSS is too faint ("bright limit is r~14.5" according to my SDSS friend) compared to what we want for ground based spectroscopy.
#
# * Use approximate relations [the first Ecliptic Plane Input Catalog](https://archive.stsci.edu/k2/KSCI-19082-001.pdf) (based on the Appendix of [Howell et al. 2012](http://adsabs.harvard.edu/abs/2012ApJ...746..123H)) to convert 2MASS J, K to approximate Kepler magnitudes.
#
# Given $x=J-K$,
#
# $$ K_p = 0.42443603 + 3.7937617 x - 2.3267277 x^2 + 1.4602553 x^3 + K $$
#
# for all stars with $J-H > 0.75$ and $H-K > 0.1$ (approximate color cut for giants), and
#
# $$ K_p = 0.314377 + 3.85667 x + 3.176111 x^2 - 25.3126 x^3 + 40.7221 x^4 - 19.2112 x^5 + K $$
#
# for all remaining stars.
#
# * Use the [K2FOV tool](http://keplerscience.arc.nasa.gov/K2/ToolsK2FOV.shtml) to narrow that list down to just the stars that will fall on silicon in Campaign 11-13.
#
# * Use this list produced in (3) to search for pairs of bright stars with separations $<N$ arcsec
#
# * Sort by $K_p$, take top 999 sources.

# %% [markdown]
# ### Import 2MASS PSC objects near the campaign FOV

# %%
# %matplotlib inline
from astropy.io import ascii
from astropy.table import Table, Column
import numpy as np
import matplotlib
matplotlib.rcParams['font.size'] = 15
import matplotlib.pyplot as plt
from os import rename

# 2MASS PSC Query: 
# ra >250 and ra <275 and dec >-33 and dec <-15 and j_m >0 and j_m <12
path = 'IPACtables/IpacTableFromSource_C11.tbl'
outputdir = 'campaign11/'
campaign_number = 11
tbl = ascii.read(path)

# %% [markdown]
# ### Calculate approximate Kepler mag $K_p$, make cuts

# %%
def JHK_to_Kp_giants(J, K):
    '''
    Convert 2MASS J, K to Kepler mag Kp for giant stars
    with J−H>0.75 and H−K>0.1
    '''
    x = J - K
    return 0.42443603 + 3.7937617*x - 2.3267277*x**2 + 1.4602553*x**3 + K

def JHK_to_Kp_other(J, K):
    '''
    Convert 2MASS J, K to Kepler mag Kp for non-giant 
    stars with J−H<0.75 and H−K<0.1
    '''
    x = J - K
    return 0.314377 + 3.85667*x + 3.176111*x**2 - 25.3126*x**3 + \
           40.7221*x**4 - 19.2112*x**5 + K

Kp = np.zeros(len(tbl['j_m']))

J = tbl['j_m']
H = tbl['h_m']
K = tbl['k_m']

giant_stars = (J-H > 0.75)*(H-K>0.1) * (-0.2 < J-K)*(J-K < 1.2)
other_stars = ~giant_stars * (-0.2 < J-K)*(J-K < 1.0) # logical not giants
Kp[giant_stars] = JHK_to_Kp_giants(J[giant_stars], K[giant_stars])
Kp[other_stars] = JHK_to_Kp_other(J[other_stars], K[other_stars])

# Impose a Kp cut for those useful to us (and reasonable)
#useful = (9 < Kp)*(Kp < 12) * other_stars
useful = (9 < Kp)*(Kp < 11.5) * other_stars
useful_tbl = tbl[useful]
useful_tbl['Kp'] = Column(Kp[useful])

def plotfield(tbl):
    # Make colormap correspond to Kepler mag
    colorscale = 1. / tbl['Kp']
    colorscale = 2*colorscale/colorscale.max() - 1
    
    fig, ax = plt.subplots(1, 2, figsize=(16,6))
    cm = plt.cm.binary
    ax[0].scatter(tbl['ra'], tbl['dec'], marker='.', 
                  alpha=0.75, color=cm(colorscale))
    ax[0].set_xlabel('RA')
    ax[0].set_ylabel('Dec')

    ax[1].hist(tbl['Kp'], 100, histtype='stepfilled',
               color='w')
    ax[1].set_ylabel('Number of candidates')
    ax[1].set_xlabel('$K_p$')
    plt.show()
    
plotfield(useful_tbl)

# %%
# Write out current table to format for K2fov:
k2fov_tbl = useful_tbl[['ra', 'dec', 'Kp', 'j_m', 'h_m', 'k_m']]
outputpath = outputdir+'k2-twos.csv'
ascii.write(k2fov_tbl, outputpath, delimiter=',', comment=False, format='no_header')

# %% [markdown]
# ### Run the tool for K2 visibility in Campaign

# %%
import K2fov
K2fov.K2onSilicon(outputpath, campaign_number)
new_png_path = outputdir + 'targets_fov.png'
new_targets_path = outputdir + 'targets_siliconFlag.csv'
rename('targets_fov.png', new_png_path)
rename('targets_siliconFlag.csv', new_targets_path)
# Out:
# WARNING:K2fov:Warning: there are 28738 sources in your target list, this could take some time
# I made two files: targets_siliconFlag.csv and targets_fov.png

# %%
# Display output file
from IPython.display import Image
Image(filename=new_png_path)

# %% [markdown]
# ### Save list of RA, Dec, $K_p$ for available targets in `on_chip.csv`

# %%
# Load flagged output file, make smaller file with just the 
# targets that fall on silicon called 'on_chip.csv'
flagged_tbl = np.loadtxt(outputdir+'targets_siliconFlag.csv', delimiter=',')

import astropy.units as u
on_chip = Table(k2fov_tbl[flagged_tbl[:,3] == 2], 
                names=['ra','dec','Kp','j','h','k'])
on_chip['ra'].unit = u.degree
on_chip['dec'].unit = u.degree

ascii.write(on_chip, outputdir+'on_chip.csv')

# %% [markdown]
# ### Show final targets for neighbor search

# %%
plotfield(on_chip)

# %% [markdown]
# # Now find pairs in the FOV:

# %%
from astropy.coordinates import SkyCoord

############################################################
# Settings #################################################

path = outputdir+'candidates_with_neighbors.txt' # output file name
recalculate = True # Calculate or use precalculated table

# Settings for the K2-two pairs
pair_separation_limits = [2, 5] # Inner and outer angle in arcmin
pair_delta_Kp = 2. # Maximum difference in Kepler magnitude

# Precautions to avoid nearby contaminant stars
contaminant_separation_limit = 0.5 # [arcmin] toss pairs with contaminants this close

# Impose a late magnitude limit to tweak number of stars produced by final cut
late_mag_limit = 11.5

# Impose a tolerance limit on color difference between pair
J_minus_H_tol = 0.08

############################################################

if recalculate:
    on_chip = ascii.read(outputdir+'on_chip.csv')
    on_chip = on_chip[on_chip['Kp'] < late_mag_limit]
    on_chip['ra'].unit = u.degree
    on_chip['dec'].unit = u.degree

    has_neighbor = np.zeros(len(on_chip['ra'])).astype(bool)
    N_neighbors = np.zeros(len(on_chip['ra']))
    
    # Store vectorized coordinates for all stars
    allstarsonchip = SkyCoord(on_chip['ra'], on_chip['dec'])

    for i, star in enumerate(on_chip):
        ra, dec, Kp, jm, hm, km = list(star)
        
        # Calculate separation, mag difference between all stars
        candidate = SkyCoord(ra, dec, unit=(u.degree, u.degree))
        separations = candidate.separation(allstarsonchip).arcmin
        deltaKp = np.abs(on_chip['Kp'] - Kp)
        J_minus_H = np.abs((on_chip['j'] - on_chip['h']) - (jm - hm))
        good_neighbors = ((separations > pair_separation_limits[0]) & 
                          (separations < pair_separation_limits[1]) &
                          (deltaKp < pair_delta_Kp) & 
                          (J_minus_H < J_minus_H_tol))
        
        # If any stars fall within separation+mag thresholds,                    
        # check if either of the stars in the candidate pair has
        # a bright star nearby that could fall into your slit
        if np.sum(good_neighbors) > 0:
            # State Farm is there.
            N_neighbors[i] = np.sum(good_neighbors)
            
            no_contaminants = np.ones(np.sum(good_neighbors)).astype(bool)
            for j, star in enumerate(on_chip[good_neighbors]):
                ra, dec, Kp, jm, hm, km  = list(star)
                candidate_with_neighbor = SkyCoord(ra, dec, unit=(u.degree, u.degree))
                separations = candidate_with_neighbor.separation(allstarsonchip).arcmin
                any_contaminants = np.sum(separations < contaminant_separation_limit)
                
                if any_contaminants > 1:
                    # There will always be at least one "contaminant" by this
                    # definition (the target star), so trigger on >1
                    no_contaminants[j] = False
                    print("Excluding star at ({0},{1}) for nearby contaminant".format(ra,dec))
            
            # If there are no nearby contaminants, mark this star as a valid
            # candidate with a neighbor
            if no_contaminants.all():
                has_neighbor[i] = True
    
    candidates_with_neighbors = on_chip[has_neighbor]
    candidates_with_neighbors.sort('Kp')
    ascii.write(candidates_with_neighbors, path, delimiter='\t', format='no_header')
else:
    candidates_with_neighbors = ascii.read(path)
    
plotfield(candidates_with_neighbors)
# Out:
# Excluding star at (261.746089,-27.36055) for nearby contaminant
# Excluding star at (253.652445,-28.257835) for nearby contaminant
# Excluding star at (254.059012,-27.782295) for nearby contaminant
# Excluding star at (254.059012,-27.782295) for nearby contaminant
# Excluding star at (257.036133,-18.438765) for nearby contaminant
# Excluding star at (257.001453,-18.040344) for nearby contaminant
# Excluding star at (257.00299,-18.038847) for nearby contaminant
# Excluding star at (264.536188,-23.422272) for nearby contaminant
# Excluding star at (257.812373,-29.944754) for nearby contaminant
# Excluding star at (259.026749,-17.733452) for nearby contaminant
# Excluding star at (258.95669,-17.524843) for nearby contaminant
# Excluding star at (258.962347,-17.526796) for nearby contaminant
# Excluding star at (259.392104,-17.875895) for nearby contaminant
# Excluding star at (259.3867,-17.877903) for nearby contaminant
# Excluding star at (259.387924,-17.870483) for nearby contaminant
# Excluding star at (257.167224,-28.047195) for nearby contaminant
# Excluding star at (257.169023,-28.051058) for nearby contaminant
# Excluding star at (267.866491,-26.660992) for nearby contaminant
# Excluding star at (260.360226,-18.277315) for nearby contaminant
# Excluding star at (260.422542,-18.048565) for nearby contaminant
# Excluding star at (257.79997,-28.101398) for nearby contaminant
# Excluding star at (268.347927,-25.526106) for nearby contaminant
# Excluding star at (261.630923,-17.58877) for nearby contaminant
# Excluding star at (261.630923,-17.58877) for nearby contaminant
# Excluding star at (261.768842,-28.720375) for nearby contaminant
# Excluding star at (261.774783,-28.725922) for nearby contaminant
# Excluding star at (262.466875,-28.704679) for nearby contaminant
# Excluding star at (262.006478,-30.534031) for nearby contaminant
# Excluding star at (262.007504,-30.536011) for nearby contaminant
# Excluding star at (262.136292,-30.241709) for nearby contaminant
# Excluding star at (262.12122,-17.772947) for nearby contaminant
# Excluding star at (262.626637,-17.000692) for nearby contaminant
# Excluding star at (262.629779,-17.00563) for nearby contaminant
# Excluding star at (262.542542,-30.256845) for nearby contaminant
# Excluding star at (262.60013,-30.155743) for nearby contaminant
# Excluding star at (262.60013,-30.155743) for nearby contaminant
# Excluding star at (262.626637,-17.000692) for nearby contaminant
# Excluding star at (262.629779,-17.00563) for nearby contaminant
# Excluding star at (262.863126,-21.564219) for nearby contaminant
# Excluding star at (263.194572,-16.829983) for nearby contaminant
# Excluding star at (263.194598,-16.828159) for nearby contaminant
# Excluding star at (263.886733,-23.855234) for nearby contaminant
# Excluding star at (263.886733,-23.855234) for nearby contaminant
# Excluding star at (263.895329,-23.856045) for nearby contaminant
# Excluding star at (266.769965,-26.12962) for nearby contaminant
# Excluding star at (266.775075,-26.135574) for nearby contaminant

# %%
fig, ax = plt.subplots()
ax.hist(N_neighbors, histtype='stepfilled', log=True, 
        color='w')
ax.set_xticks(range(5))
ax.set_xlabel('Number of matches found')
ax.set_ylabel('Frequency')
ax.set_title('How many stars actually have\nmore than one match?')
plt.show()

for i in range(5):
    print("Number of stars with {0} matching comparisons: {1}".format(i, 
          list(N_neighbors).count(i)))
# Out:
# Number of stars with 0 matching comparisons: 4452
# Number of stars with 1 matching comparisons: 947
# Number of stars with 2 matching comparisons: 132
# Number of stars with 3 matching comparisons: 18
# Number of stars with 4 matching comparisons: 7

# %%
print 'Total targets:', len(candidates_with_neighbors)
# Out:
# Total targets: 1071

# %%
from astroquery.simbad import Simbad
customSimbad = Simbad()
customSimbad.add_votable_fields('sptype')

c = SkyCoord(ra=candidates_with_neighbors['ra'], dec=candidates_with_neighbors['dec'])
#arg = np.argmin(c.separation(c[target])[1:]) + 1
ok = 0
not_ok = 0
coolstars = np.zeros(len(c))
for i, target in enumerate(c):
    if coolstars[i] != 1:
        a = c.separation(target).arcmin
        target_coord = target.to_string()
        target_sptype = customSimbad.query_region(target_coord, radius=25 * u.arcsec)
        a[i] = 1e5
        comp_ind = np.argmin(a)
        comp_coord = c[comp_ind].to_string()
        coord_sptype = customSimbad.query_region(comp_coord, radius=25 * u.arcsec)
        if target_sptype is not None and coord_sptype is not None:
            spectypes = target_sptype['SP_TYPE'][0] + coord_sptype['SP_TYPE'][0]
            if 'A' in spectypes or 'B' in spectypes or 'O' in spectypes:
                pass
            else:
                coolstars[i] = 1
                coolstars[comp_ind] = 1
cool_candidates = candidates_with_neighbors[coolstars.astype(bool)]
print(len(cool_candidates))

plotfield(cool_candidates)
# Out:
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:47:32.448 -25:21:52.668': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:20:30.552 -29:23:55.428': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:54:16.392 -26:46:38.28': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:19:56.952 -25:51:13.788': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:27:30.288 -25:27:08.028': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:23:05.112 -26:00:02.592': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:27:39.672 -30:03:31.032': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:07:22.2 -25:02:35.952': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:39:43.968 -29:21:37.512': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:52:08.688 -26:16:17.868': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:05:42 -19:22:18.588': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:20:47.112 -18:06:56.988': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:25:17.4 -29:34:57.468': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:31:03.912 -18:39:13.068': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:40:00.552 -21:07:42.348': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:53:11.088 -25:22:39.828': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:58:29.112 -26:25:03.108': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:07:32.232 -24:41:53.988': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:50:29.4 -25:57:09.108': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:25:17.328 -29:48:00.468': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:51:28.152 -24:19:50.628': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:58:25.968 -25:20:31.92': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:23:10.608 -24:28:26.868': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:28:08.208 -21:55:53.148': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:17:33.432 -21:43:28.272': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:43:20.712 -28:25:05.88': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:16:48.768 -30:53:24.828': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:24:39.672 -26:18:20.628': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:40:56.952 -28:23:50.028': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:37:28.368 -28:44:24.468': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:27:39 -30:25:30': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:11:22.2 -31:10:45.12': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:30:30 -30:09:20.628': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:39:24.6 -21:03:45': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:10:49.248 -19:18:27.828': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:11:04.128 -19:20:22.668': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:05:49.512 -26:52:35.148': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:26:41.4 -30:12:53.748': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:17:12.768 -30:24:10.152': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:26:22.872 -28:38:29.508': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:33:18.312 -19:23:51.828': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:16:29.088 -18:49:42.672': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:05:13.008 -24:12:26.028': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:00:40.632 -28:40:04.188': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:33:18 -20:53:07.908': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:44:59.832 -19:57:49.068': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:45:18.528 -19:58:57': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:31:07.488 -17:10:01.668': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:01:58.128 -26:57:30.708': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:51:50.928 -21:27:44.028': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:00:34.608 -27:33:06.588': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:00:50.712 -27:35:43.548': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:51:37.488 -25:35:33.468': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:52:21.408 -26:05:29.508': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:15:14.688 -20:53:32.352': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:48:04.128 -26:52:32.232': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:03:05.4 -28:23:39.948': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:00:04.128 -26:43:50.592': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:04:07.992 -28:32:40.308': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:03:54.288 -28:29:57.192': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:37:48.6 -29:33:28.548': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:37:31.488 -29:31:21.108': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:44:48.528 -20:59:26.988': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:44:46.848 -20:54:47.628': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:29:06.048 -20:19:11.748': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:29:00.6 -20:23:56.148': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:31:23.808 -23:02:40.992': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:58:06 -27:43:43.068': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:12:53.592 -25:18:15.12': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:06:01.248 -26:40:31.548': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:51:07.8 -22:48:04.788': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:51:03.648 -22:43:16.428': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:05:23.088 -27:01:12.468': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:49:55.968 -25:01:00.588': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:50:11.088 -25:01:40.512': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:31:39.192 -30:29:12.552': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:14:16.632 -17:21:15.192': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:56:00.768 -25:30:08.748': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:23:12.768 -18:59:04.668': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:05:18.768 -23:38:53.952': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:52:06.312 -24:43:54.228': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:52:30.768 -24:44:20.148': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:05:18.528 -24:49:49.188': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:23:02.928 -26:06:12.708': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:22:51.912 -26:02:55.428': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:17:32.232 -21:39:36.828': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:25:07.728 -24:28:06.672': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:25:58.152 -29:08:19.428': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:16:06.528 -17:44:00.708': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:22:12.288 -21:20:44.988': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:22:16.152 -21:18:01.188': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:45:33.432 -21:12:10.188': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '16:57:25.728 -23:58:06.672': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:37:17.832 -28:21:13.428': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:25:19.032 -26:27:19.548': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:25:04.128 -24:36:09.432': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:25:26.208 -30:06:45.108': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:26:44.448 -16:58:39.432': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:25:17.328 -26:23:38.112': No astronomical object found :
#   (error.line, error.msg))
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:13:41.088 -31:07:49.908': No astronomical object found :
#   (error.line, error.msg))
# 515
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astroquery/simbad/core.py:853: UserWarning: Warning: The script line number 3 raised an error (recorded in the `errors` attribute of the result table): '17:51:27.888 -26:39:40.68': No astronomical object found :
#   (error.line, error.msg))

# %%
from astroplan.plots import plot_finder_image
from astroplan import FixedTarget

ft1 = FixedTarget(coord=c[target])
ft2 = FixedTarget(coord=c[arg])

#fig, ax = plt.subplots(1, 2, figsize=(14, 6))
plot_finder_image(ft1, reticle=True)#, ax=ax[0])
plt.figure()
plot_finder_image(ft2, reticle=True)#, ax=ax[1])
# Out:
# WARNING: OldEarthOrientationDataWarning: Your version of the IERS Bulletin A is 17.3 days old. For best precision (on the order of arcseconds), you must download an up-to-date IERS Bulletin A table. To do so, run:
#
# >>> from astroplan import download_IERS_A
# >>> download_IERS_A()
#  [astroplan.utils]
# WARNING:astropy:OldEarthOrientationDataWarning: Your version of the IERS Bulletin A is 17.3 days old. For best precision (on the order of arcseconds), you must download an up-to-date IERS Bulletin A table. To do so, run:
#
# >>> from astroplan import download_IERS_A
# >>> download_IERS_A()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-91f5f7c1eb53> in <module>()
#       2 from astroplan import FixedTarget
#       3
# ----> 4 ft1 = FixedTarget(coord=c[target])
#       5 ft2 = FixedTarget(coord=c[arg])
#       6
#
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astropy/coordinates/sky_coordinate.pyc in __getitem__(self, item)
#     236             # First turn `self` into a mockup of the thing we want - we can copy
#     237             # this to get all the right attributes
# --> 238             self._sky_coord_frame = self_frame[item]
#     239             out = SkyCoord(self, representation=self.representation)
#     240
#
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astropy/coordinates/baseframe.pyc in __getitem__(self, view)
#     993     def __getitem__(self, view):
#     994         if self.has_data:
# --> 995             out = self.realize_frame(self.data[view])
#     996             out.representation = self.representation
#     997             return out
#
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astropy/coordinates/representation.pyc in __getitem__(self, view)
#     117     def __getitem__(self, view):
#     118         return self.__class__(*[getattr(self, component)[view]
# --> 119                                 for component in self.components])
#     120
#     121     def __len__(self):
#
# /astro/users/bmmorris/.local/lib/python2.7/site-packages/astropy/units/quantity.pyc in __getitem__(self, key)
#     891     def __getitem__(self, key):
#     892         try:
# --> 893             out = super(Quantity, self).__getitem__(key)
#     894         except IndexError:
#     895             # We want zero-dimensional Quantity objects to behave like scalars,
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
# Match up EPIC list with my list, fill in missing rows from EPIC list with my rows
# http://archive.stsci.edu/k2/epic/search.php
EPIC_list_path = outputdir+'EPIC_list.txt'
EPIC_list = open(EPIC_list_path, 'r').read().split('\n\n')
candidate_array = candidates_with_neighbors.as_array()
final_list = []
cadence = '30'
for i, line in enumerate(EPIC_list):
    if 'no rows' not in line and len(line) > 0:
        final_list.append(line+'\t'+cadence)
    elif len(line) > 0:
        my_row = list(candidate_array[i])
        my_row.append(cadence)
        final_list.append('\t'.join(map(str, my_row)))
        
final_output_path = '{}campaign_{}_EPIC_list.txt'.format(outputdir, campaign_number)
with open(final_output_path, 'w') as f:
    f.write('\n'.join(final_list))
